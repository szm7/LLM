# %%
# %pip install -qU langchain-groq
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage

# %%
APIKEY = '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'
groq = ChatGroq(model="llama3-70b-8192", api_key=APIKEY)

# %%
def responseGROQ(prompt):
    message = HumanMessage(content=prompt)
    response = groq.invoke([message])
    return response.content

# %%
prompt = input("Prompt : ")
output = responseGROQ(prompt)
print(output)
# Out:
# Real Madrid! One of the most successful, storied, and beloved football clubs in the world. Here's a brief overview:
#
# **History**
#
# Real Madrid was founded in 1902 in Madrid, Spain, and has since become a legendary club in the world of football. The team has won a record 13 European Cup/UEFA Champions League titles, 34 Spanish league titles, and numerous other domestic and international trophies.
#
# **Home Stadium**
#
# Real Madrid plays its home matches at the Santiago Bernabéu Stadium, which has a seating capacity of over 81,000. The stadium is considered one of the most iconic and intimidating venues in football, with a electric atmosphere that can unnerve opposing teams.
#
# **Rivals**
#
# Real Madrid has two major rivals: Barcelona (El Clásico) and Atlético Madrid (El Derbi madrileño). The rivalry with Barcelona is one of the fiercest and most intense in football, with the two teams competing for supremacy in Spain and Europe.
#
# **Success**
#
# ...

# %% [markdown]
# Gemini Result

# %% [markdown]
# ![Screenshot 2024-07-14 at 9.20.53 PM.png](<attachment:Screenshot 2024-07-14 at 9.20.53 PM.png>)

# %% [markdown]
# ChatGPT result

# %% [markdown]
# ![Screenshot 2024-07-14 at 9.23.38 PM.png](<attachment:Screenshot 2024-07-14 at 9.23.38 PM.png>)

# %%
prompt = input("Prompt : ")
output = responseGROQ(prompt)
print(output)
# Out:
# Real Madrid!
#
# Real Madrid is a professional football club based in Madrid, Spain. The club is one of the most successful and valuable sports teams in the world, with a rich history and a massive global following.
#
# Here's a brief definition:
#
# **Name:** Real Madrid Club de Fútbol (Royal Madrid Football Club)
#
# **Founded:** 1902 (as Madrid Football Club)
#
# **Nickname:** Los Blancos (The Whites) or Los Merengues (The Meringues)
#
# **Home Stadium:** Santiago Bernabéu Stadium (capacity: over 81,000)
#
# **League:** La Liga (Spanish top division)
#
# **Achievements:**
#
# * Record 13 European Cup/UEFA Champions League titles
# * Record 34 Spanish league titles (La Liga)
# * 19 Copa del Rey (Spanish Cup) titles
# * 2 UEFA Super Cups
# * 1 FIFA Club World Cup
# * 1 Intercontinental Cup
#
# **Notable players:** Cristiano Ronaldo, Lionel Messi, Zinedine Zidane, Luís Figo, Raúl González, Ferenc Puskás, Alfredo Di Stéfano, and many more.
#
# ...

# %%
prompt = input("Prompt : ")
output = responseGROQ(prompt)
print(output)
# Out:
# A iconic combination!
#
# The Santiago Bernabéu Stadium is the home stadium of Real Madrid CF, one of the most successful and prestigious football clubs in the world. Located in Madrid, Spain, the stadium has a seating capacity of over 81,000 spectators, making it one of the largest stadiums in Europe.
#
# Real Madrid has a rich history in the Champions League, having won a record 13 titles, including a streak of five consecutive titles from 1956 to 1960. The club has also won the competition in 1966, 1998, 2000, 2002, 2014, 2016, 2017, and 2018.
#
# The Santiago Bernabéu Stadium has hosted numerous Champions League matches, including several finals. In 2010, the stadium hosted the Champions League Final between Inter Milan and Bayern Munich, which Inter Milan won 2-0.
#
# ...
